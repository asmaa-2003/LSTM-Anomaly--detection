# %% [markdown]
# <a href="https://colab.research.google.com/github/asmaa-2003/LSTM-Anomaly--detection/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("MetroPT2.csv")
df.head()
# Out:
#                  timestamp    TP2    TP3     H1  DV_pressure  Reservoirs  \
# 0  2022-04-28 12:33:29.120 -0.014  8.060  1.136       -0.020       8.066
# 1  2022-04-28 12:33:30.111  0.156  8.058 -0.020       -0.018       8.066
# 2  2022-04-28 12:33:31.102  1.094  8.058 -0.026       -0.018       8.066
# 3  2022-04-28 12:33:32.093  2.482  8.058 -0.026       -0.018       8.064
# 4  2022-04-28 12:33:33.084  3.756  8.058 -0.024       -0.018       8.066
#
#    Oil_temperature  Flowmeter  Motor_current  COMP  ...  Towers  MPG  LPS  \
# 0           57.125       0.25         4.9100   0.0  ...     0.0  0.0  0.0
# 1           57.200       0.25         4.7325   0.0  ...     0.0  0.0  0.0
# 2           57.150       0.25         4.9100   0.0  ...     0.0  0.0  0.0
# 3           57.125       0.25         4.8200   0.0  ...     0.0  0.0  0.0
# 4           57.075       0.25         4.9100   0.0  ...     0.0  0.0  0.0
#
#    Pressure_switch  Oil_level  Caudal_impulses     gpsLat   gpsLong  gpsSpeed  \
# ...

# %%
df = df.drop(columns=['timestamp'])
df = df.fillna(df.median(numeric_only=True))
df.shape
# Out:
# (12631, 20)

# %%
threshold = df['Motor_current'].quantile(0.99)

df['Target'] = (df['Motor_current'] > threshold).astype(int)

df['Target'].value_counts()
# Out:
# Target
# 0    12505
# 1      126
# Name: count, dtype: int64

# %%
X = df.drop(['Target', 'Motor_current'], axis=1)
y = df['Target']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.33,
    random_state=42,
    stratify=y
)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_features': ['sqrt', 'log2'],
    'max_depth': [10, 15, 20, None],
    'criterion': ['gini', 'entropy']
}

CV_model = GridSearchCV(model, param_grid, cv=5, scoring='f1')
CV_model.fit(X_train, y_train)

CV_model.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 15,
#  'max_features': 'sqrt',
#  'n_estimators': 200}

# %%
best = CV_model.best_params_

mdl = RandomForestClassifier(
    n_estimators=best['n_estimators'],
    max_features=best['max_features'],
    max_depth=best['max_depth'],
    criterion=best['criterion'],
    random_state=42
)

mdl.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=15, n_estimators=200,
#                        random_state=42)

# %%
y_pred = mdl.predict(X_test)

# %%
print("F1 Score:", f1_score(y_test, y_pred))

print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(cm).plot()
plt.title("Random Forest - MetroPT2")
plt.show()
# Out:
# F1 Score: 0.4358974358974359
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      4127
#            1       0.47      0.40      0.44        42
#
#     accuracy                           0.99      4169
#    macro avg       0.73      0.70      0.72      4169
# weighted avg       0.99      0.99      0.99      4169

# %%
importances = mdl.feature_importances_

feat_df = pd.DataFrame({
    "Feature": X.columns,
    "Importance": importances
}).sort_values(by="Importance", ascending=False)

feat_df
# Out:
#             Feature  Importance
# 0               TP2    0.282287
# 1               TP3    0.109356
# 4        Reservoirs    0.104521
# 2                H1    0.097247
# 7              COMP    0.093981
# 8        DV_eletric    0.081059
# 10              MPG    0.073822
# 5   Oil_temperature    0.063956
# 15           gpsLat    0.024867
# 16          gpsLong    0.023781
# 17         gpsSpeed    0.017680
# 3       DV_pressure    0.012521
# 9            Towers    0.011517
# 18       gpsQuality    0.003156
# 12  Pressure_switch    0.000249
# 6         Flowmeter    0.000000
# 14  Caudal_impulses    0.000000
# 11              LPS    0.000000
# 13        Oil_level    0.000000

# %%
plt.barh(feat_df["Feature"], feat_df["Importance"])
plt.title("Feature Importance - MetroPT2")
plt.show()
