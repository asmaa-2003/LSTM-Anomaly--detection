# %% [markdown]
# <a href="https://colab.research.google.com/github/asmaa-2003/LSTM-Anomaly--detection/blob/main/notebook3_metropt1_fixed_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 3 — Interpretable Rules for Online Failure Prediction
# **Paper:** *Interpretable rules for online failure prediction: a case study on metro do porto datasets*
# Jakobs, Veloso, Gama — IJDSA (2026)
#
# **Dataset:** MetroPT1 (January 1 – June 2, 2022)
# **Known failures (from paper Table 1):**
# - Air Leak : 2022-02-11 19:46 → 2022-02-12 01:46 | LPS peak: 2022-02-11 19:46 (episode 31, 360 min)
# - Oil Leak : 2022-02-28 22:50 → 2022-03-01 02:00 | LPS peak: 2022-02-28 22:50 (episode 46, 189 min)
#
# **Exact paper pipeline:**
# 1. Temporal split: train (before 2022-03-15), test (from 2022-03-15)
#    ← CUTOFF moved past both failures so Train failures = 0
# 2. LPS excluded from features (paper §2)
# 3. Normalize per channel (mean/std from train)
# 4. Sliding windows: L=1800 (30-min), stride d=300 (5-min)
# 5. Convolutional AE: N=10 blocks, dilation=2^i, 30 kernels, kernel=3, dropout=0.2, embed=32
# 6. Last 30% of train → validation → estimate τ_anom = β × q99
# 7. Low-pass filter: z_t = z_{t-1} + α(y_t − z_{t-1})
# 8. Failure if p(failure) > τ_fail = 0.5
# 9. Best config (paper Table 3): α=0.05, β=1
# 10. Online Rule-Learning (Algorithm 1): Decision Trees on φ(x)=[var,min,max,mean]
# 11. Compare vs AMRules, report support & nA

# %%
# ── 0. Installs ────────────────────────────────────────────────────────────
import subprocess, sys
for p in ['tensorflow','scikit-learn','pandas','numpy','matplotlib']:
    subprocess.check_call([sys.executable,'-m','pip','install',p,'--quiet'])
print('Done')
# Out:
# Done

# %%
# ── 1. Imports ─────────────────────────────────────────────────────────────
import warnings, os
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier, export_text

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks

OUTPUT_DIR = os.path.join(os.getcwd(), 'outputs')
os.makedirs(OUTPUT_DIR, exist_ok=True)

SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
print('Imports OK')
# Out:
# Imports OK

# %%
# ── 2. Load MetroPT1 ───────────────────────────────────────────────────────
CSV = 'MetroPT1.csv'   # ← غيّر المسار إذا لزم

df = pd.read_csv(CSV, parse_dates=['timestamp'])
df = df.sort_values('timestamp').reset_index(drop=True)

print(f'Shape     : {df.shape}')
print(f'Date range: {df.timestamp.min()} → {df.timestamp.max()}')
print(f'Columns   : {df.columns.tolist()}')
# Out:
# Shape     : (10773588, 21)
# Date range: 2022-01-01 06:00:00 → 2022-06-02 15:49:53
# Columns   : ['timestamp', 'TP2', 'TP3', 'H1', 'DV_pressure', 'Reservoirs', 'Oil_temperature', 'Flowmeter', 'Motor_current', 'COMP', 'DV_eletric', 'Towers', 'MPG', 'LPS', 'Pressure_switch', 'Oil_level', 'Caudal_impulses', 'gpsLong', 'gpsLat', 'gpsSpeed', 'gpsQuality']

# %% [markdown]
# ### اكتشاف الأعطال الحقيقية من البيانات
#
# بعد فحص كل نوبات `LPS=1` وتجميعها في episodes (فجوة > 10 دقائق تفصل بين النوبات)، وجدنا:
#
# | # | البداية | النهاية | المدة | التفسير |
# |---|---------|---------|-------|---------|
# | 31 | 2022-02-11 19:46 | 2022-02-12 01:46 | **360 دقيقة** | ✅ **Air Leak** |
# | 46 | 2022-02-28 22:50 | 2022-03-01 02:00 | **189 دقيقة** | ✅ **Oil Leak** |
# | بقية النوبات | — | — | < 37 دقيقة | توقف طبيعي للمترو |
#
# > **ملاحظة حرجة:** كلا العطلين يقعان في **فبراير** — قبل الـ CUTOFF الأصلي (1 مارس).
# > لذلك **نحرك الـ CUTOFF إلى 2022-03-15** لضمان `Train failures = 0`.
# > الأعطال ستكون في الـ Train لكن بدون label، والنموذج سيكتشف شذوذها عبر reconstruction error.

# %%
# ── 3. Define known failures — discovered from LPS=1 episodes ────────────
# Episode 31: 2022-02-11 19:46 → 2022-02-12 01:46 | duration=360 min → Air Leak
# Episode 46: 2022-02-28 22:50 → 2022-03-01 02:00 | duration=189 min → Oil Leak
# All other LPS=1 episodes < 37 min → normal metro stops, not failures
# LPS=1 means LOW PRESSURE (anomaly); LPS=0 is normal operation

FAILURES = [
    {
        'name'     : 'Air Leak',
        'start'    : pd.Timestamp('2022-02-11 19:46:31'),
        'end'      : pd.Timestamp('2022-02-12 01:46:49'),
        'lps_time' : pd.Timestamp('2022-02-11 19:46:31'),  # first LPS=1
        'goal'     : pd.Timestamp('2022-02-11 17:46:31'),  # 2h before LPS
    },
    {
        'name'     : 'Oil Leak',
        'start'    : pd.Timestamp('2022-02-28 22:50:43'),
        'end'      : pd.Timestamp('2022-03-01 02:00:00'),
        'lps_time' : pd.Timestamp('2022-02-28 22:50:43'),  # first LPS=1
        'goal'     : pd.Timestamp('2022-02-28 20:50:43'),  # 2h before LPS
    }
]

# Create ground-truth failure label from known periods
df['failure_label'] = 0
for f in FAILURES:
    mask = (df['timestamp'] >= f['start']) & (df['timestamp'] <= f['end'])
    df.loc[mask, 'failure_label'] = 1

print('Failure label distribution:')
print(df['failure_label'].value_counts())
print(f'Failure ratio: {df.failure_label.mean()*100:.4f}%')
print(f'\nAir Leak  : {FAILURES[0]["start"]} → {FAILURES[0]["end"]}')
print(f'Oil Leak  : {FAILURES[1]["start"]} → {FAILURES[1]["end"]}')
# Out:
# Failure label distribution:
# failure_label
# 0    10740611
# 1       32977
# Name: count, dtype: int64
# Failure ratio: 0.3061%
#
# Air Leak  : 2022-02-11 19:46:31 → 2022-02-12 01:46:49
# Oil Leak  : 2022-02-28 22:50:43 → 2022-03-01 02:00:00

# %%
# ── 4. Feature selection — paper §2 ───────────────────────────────────────
# LPS: "used neither for training nor testing" → excluded
# GPS columns: not sensor-APU data → excluded
# Flowmeter: INCLUDED (key sensor in paper findings)

FEATURE_COLS = [
    'TP2','TP3','H1','DV_pressure','Reservoirs',
    'Oil_temperature','Flowmeter','Motor_current',
    'COMP','DV_eletric','Towers','MPG',
    'Pressure_switch','Oil_level','Caudal_impulses'
]

# Verify all columns exist
missing = [c for c in FEATURE_COLS if c not in df.columns]
if missing:
    print(f'WARNING — missing columns: {missing}')
    FEATURE_COLS = [c for c in FEATURE_COLS if c in df.columns]

print(f'Using {len(FEATURE_COLS)} features: {FEATURE_COLS}')
# Out:
# Using 15 features: ['TP2', 'TP3', 'H1', 'DV_pressure', 'Reservoirs', 'Oil_temperature', 'Flowmeter', 'Motor_current', 'COMP', 'DV_eletric', 'Towers', 'MPG', 'Pressure_switch', 'Oil_level', 'Caudal_impulses']

# %% [markdown]
# ### ⚠️ مشكلة هيكلية في MetroPT1
#
# **الواقع:** كلا العطلين (Air Leak: 11 فبراير، Oil Leak: 28 فبراير) يقعان **قبل** أي CUTOFF معقول.
#
# | خيار CUTOFF | Train failures | Test failures | المشكلة |
# |-------------|---------------|---------------|----------|
# | 2022-03-01 | 33,019 ❌ | 0 | AE يتعلم على أعطال |
# | 2022-03-15 | 0 ✅ | 0 ❌ | لا يوجد ground truth في Test |
# | 2022-01-01 | 0 ✅ | 33,019 ✅ | Train فارغ تقريباً |
#
# **الخياران العمليان:**
#
# **① CUTOFF = 2022-02-11** (قبل أول عطل بيوم)
# - Train: يناير + أوائل فبراير (نظيفة) → AE يتعلم الطبيعي
# - Test: من 11 فبراير → يحتوي كلا العطلين كاملَين ✅
#
# **② اتباع نهج الورقة بدقة** — الورقة ربما استخدمت MetroPT1 بشكل مختلف
# - راجع Table 1 في الورقة للأوقات الدقيقة لـ MetroPT1
#
# > **الحل المختار أدناه: CUTOFF = 2022-02-10** — يضع كلا العطلين في Test ✅

# %%
# ── 5. Temporal train/test split — cutoff = 2022-02-10 ───────────────────
# CUTOFF = 2022-02-10 (يوم قبل أول عطل: Air Leak 11 فبراير)
# - Train: 2022-01-01 → 2022-02-09  (بيانات طبيعية فقط ✓)
# - Test : 2022-02-10 → 2022-06-02  (يحتوي كلا العطلين كاملَين ✓)

CUTOFF = pd.Timestamp('2022-02-10')

df_train = df[df['timestamp'] < CUTOFF].copy()
df_test  = df[df['timestamp'] >= CUTOFF].copy()

print(f'Train: {len(df_train):,} rows | {df_train.timestamp.min()} → {df_train.timestamp.max()}')
print(f'Test : {len(df_test):,} rows  | {df_test.timestamp.min()} → {df_test.timestamp.max()}')
print(f'Train failures: {df_train.failure_label.sum():,}')
print(f'Test  failures: {df_test.failure_label.sum():,}')
# Out:
# Train: 2,871,785 rows | 2022-01-01 06:00:00 → 2022-02-09 23:59:59
# Test : 7,901,803 rows  | 2022-02-10 00:00:00 → 2022-06-02 15:49:53
# Train failures: 0
# Test  failures: 32,977

# %%
# ── 5b. Sanity check — Train يجب أن تكون نظيفة ────────────────────────────
train_fail = df_train['failure_label'].sum()
test_fail  = df_test['failure_label'].sum()

print(f'Train failures: {train_fail}')
print(f'Test  failures: {test_fail}')

assert train_fail == 0, f'خطأ! AE لا يمكنه التدريب على بيانات تحتوي أعطالاً ({train_fail} صف)'
print('✓ Train failures = 0 — آمن للتدريب')

# Note: كلا العطلين في فبراير (قبل 15 مارس) → label=0 في df لأن failure_label
# يُحدَّد بناءً على نطاقات FAILURES التي تنتهي قبل CUTOFF
# لكن الـ anomaly score سيرتفع في تلك الفترة لأن السيارة كانت تسير بشكل غير طبيعي
# Out:
# Train failures: 0
# Test  failures: 32977
# ✓ Train failures = 0 — آمن للتدريب

# %%
# ── 6. Normalisation — fit on train only (paper §5.1) ─────────────────────
train_vals = df_train[FEATURE_COLS].values.astype(np.float32)
test_vals  = df_test[FEATURE_COLS].values.astype(np.float32)

col_means = np.nanmean(train_vals, axis=0)
col_stds  = np.nanstd(train_vals, axis=0)
col_stds[col_stds == 0] = 1.0

# Fill NaN with column mean
for i in range(train_vals.shape[1]):
    train_vals[np.isnan(train_vals[:,i]), i] = col_means[i]
    test_vals[np.isnan(test_vals[:,i]), i]   = col_means[i]

X_train_norm = (train_vals - col_means) / col_stds
X_test_norm  = (test_vals  - col_means) / col_stds

print(f'Train normalised: {X_train_norm.shape}')
print(f'Test  normalised: {X_test_norm.shape}')
# Out:
# Train normalised: (2871785, 15)
# Test  normalised: (7901803, 15)

# %%
# ── 7. Sliding windows L=1800 (30-min), stride d=300 (5-min) ─────────────
# Paper §5.1: "overlapping windows of 30 min (L=1800) with a stride of 5 min (d=300)"
# Note: data is ~1Hz so 1800 samples = 30 min

L = 1800
D = 300

def make_windows(X, L, D):
    return np.array([X[i:i+L] for i in range(0, len(X)-L+1, D)],
                    dtype=np.float32)

def window_labels(y, L, D):
    return np.array([int(y[i:i+L].max()) for i in range(0, len(y)-L+1, D)])

def window_timestamps(ts, L, D):
    return np.array([ts[i] for i in range(0, len(ts)-L+1, D)])

y_train_raw = df_train['failure_label'].values
y_test_raw  = df_test['failure_label'].values
ts_train    = df_train['timestamp'].values
ts_test     = df_test['timestamp'].values

W_train      = make_windows(X_train_norm, L, D)
W_test       = make_windows(X_test_norm,  L, D)
y_train_win  = window_labels(y_train_raw, L, D)
y_test_win   = window_labels(y_test_raw,  L, D)
ts_train_win = window_timestamps(ts_train, L, D)
ts_test_win  = window_timestamps(ts_test,  L, D)

ts_test_pd = pd.to_datetime(ts_test_win)

print(f'Train windows: {W_train.shape} | failures: {y_train_win.sum()}')
print(f'Test  windows: {W_test.shape}  | failures: {y_test_win.sum()}')
# Out:
# Train windows: (9567, 1800, 15) | failures: 0
# Test  windows: (26334, 1800, 15)  | failures: 122

# %%
# ── 8. Validation split — last 30% of train windows (paper §5.1) ──────────
n_train   = len(W_train)
val_start = int(n_train * 0.70)

W_tr  = W_train[:val_start]
W_val = W_train[val_start:]
y_tr  = y_train_win[:val_start]

# AE trained on NORMAL windows only
W_tr_normal = W_tr[y_tr == 0]

print(f'AE train (normal only): {W_tr_normal.shape}')
print(f'Validation windows    : {W_val.shape}')
# Out:
# AE train (normal only): (6696, 1800, 15)
# Validation windows    : (2871, 1800, 15)

# %%
# ── 9. Subsample windows for training speed (keep architecture exact) ──────
# Full L=1800 on CPU is very slow — subsample timesteps within each window
# Architecture stays identical; only temporal resolution is reduced
STEP = 6   # every 6th sample → 300 timesteps per window (5-min resolution)
SEQ  = L // STEP

W_tr_ae   = W_tr_normal[:, ::STEP, :]  # (n, 300, C)
W_val_ae  = W_val[:, ::STEP, :]
W_test_ae = W_test[:, ::STEP, :]

N_FEAT = len(FEATURE_COLS)
print(f'AE input: ({SEQ}, {N_FEAT})')
print(f'Train AE samples: {W_tr_ae.shape[0]}')
# Out:
# AE input: (300, 15)
# Train AE samples: 6696

# %%
# ── 10. Build Convolutional AE (paper §4.1, Fig.1) ─────────────────────────
# N=10 encoder+decoder blocks
# Each block: Conv1D(30 kernels, kernel=3, dilation=2^i) + BN + ReLU + Dropout(0.2)
# Skip connections; embedding dim=32

def build_conv_ae(seq_len, n_feat, N=10, n_k=30, emb=32, drop=0.2):
    inp = keras.Input(shape=(seq_len, n_feat))
    enc_outs = []
    x = inp
    for i in range(N):
        dil = min(2**i, seq_len//2)
        x = layers.Conv1D(n_k, 3, padding='causal', dilation_rate=dil)(x)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)
        x = layers.Dropout(drop)(x)
        enc_outs.append(x)
    # Bottleneck
    x = layers.Conv1D(emb, 1, activation='relu')(x)
    # Decoder with skip connections
    for i in range(N-1, -1, -1):
        dil = min(2**i, seq_len//2)
        skip = enc_outs[i]
        if x.shape[-1] != skip.shape[-1]:
            x = layers.Conv1D(skip.shape[-1], 1)(x)
        x = layers.Add()([x, skip])
        x = layers.Conv1D(n_k, 3, padding='causal', dilation_rate=dil)(x)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)
        x = layers.Dropout(drop)(x)
    out = layers.TimeDistributed(layers.Dense(n_feat))(x)
    model = keras.Model(inp, out)
    model.compile(optimizer=keras.optimizers.Adam(1e-4), loss='mse')
    return model

ae = build_conv_ae(SEQ, N_FEAT)
ae.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 300, 15)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 300, 30)   │      1,380 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 300, 30)   │        120 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 300, 30)   │          0 │ re_lu[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 300, 30)   │      2,730 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 300, 30)   │          0 │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 300, 30)   │      2,730 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 300, 30)   │          0 │ re_lu_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 300, 30)   │      2,730 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 300, 30)   │          0 │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 300, 30)   │      2,730 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 300, 30)   │          0 │ re_lu_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 300, 30)   │      2,730 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 300, 30)   │          0 │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 300, 30)   │      2,730 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 300, 30)   │          0 │ re_lu_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 300, 30)   │      2,730 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 300, 30)   │          0 │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 300, 30)   │      2,730 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 300, 30)   │          0 │ re_lu_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 300, 30)   │      2,730 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 300, 30)   │          0 │ re_lu_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, 300, 32)   │        992 │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_11 (Conv1D)  │ (None, 300, 30)   │        990 │ conv1d_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 300, 30)   │          0 │ conv1d_11[0][0],  │
# │                     │                   │            │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_12 (Conv1D)  │ (None, 300, 30)   │      2,730 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 300, 30)   │          0 │ re_lu_10[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 300, 30)   │          0 │ dropout_10[0][0], │
# │                     │                   │            │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_13 (Conv1D)  │ (None, 300, 30)   │      2,730 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_13[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 300, 30)   │          0 │ re_lu_11[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 300, 30)   │          0 │ dropout_11[0][0], │
# │                     │                   │            │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_14 (Conv1D)  │ (None, 300, 30)   │      2,730 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_14[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 300, 30)   │          0 │ re_lu_12[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 300, 30)   │          0 │ dropout_12[0][0], │
# │                     │                   │            │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_15 (Conv1D)  │ (None, 300, 30)   │      2,730 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_15[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 300, 30)   │          0 │ re_lu_13[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 300, 30)   │          0 │ dropout_13[0][0], │
# │                     │                   │            │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, 300, 30)   │      2,730 │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 300, 30)   │          0 │ re_lu_14[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 300, 30)   │          0 │ dropout_14[0][0], │
# │                     │                   │            │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, 300, 30)   │      2,730 │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 300, 30)   │          0 │ re_lu_15[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 300, 30)   │          0 │ dropout_15[0][0], │
# │                     │                   │            │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_18 (Conv1D)  │ (None, 300, 30)   │      2,730 │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 300, 30)   │          0 │ re_lu_16[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 300, 30)   │          0 │ dropout_16[0][0], │
# │                     │                   │            │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_19 (Conv1D)  │ (None, 300, 30)   │      2,730 │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_19[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 300, 30)   │          0 │ re_lu_17[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 300, 30)   │          0 │ dropout_17[0][0], │
# │                     │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_20 (Conv1D)  │ (None, 300, 30)   │      2,730 │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_20[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 300, 30)   │          0 │ re_lu_18[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 300, 30)   │          0 │ dropout_18[0][0], │
# │                     │                   │            │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_21 (Conv1D)  │ (None, 300, 30)   │      2,730 │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 300, 30)   │        120 │ conv1d_21[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_19 (ReLU)     │ (None, 300, 30)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 300, 30)   │          0 │ re_lu_19[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed    │ (None, 300, 15)   │        465 │ dropout_19[0][0]  │
# │ (TimeDistributed)   │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 58,097 (226.94 KB)
#  Trainable params: 56,897 (222.25 KB)
#  Non-trainable params: 1,200 (4.69 KB)

# %%
# ── 11. Train AE — max 200 epochs, Adam lr=1e-4 (paper §5.1) ──────────────
es = callbacks.EarlyStopping(
    monitor='val_loss', patience=15, restore_best_weights=True)

hist = ae.fit(
    W_tr_ae, W_tr_ae,
    epochs=200, batch_size=32,
    validation_data=(W_val_ae, W_val_ae),
    callbacks=[es], verbose=1
)
print(f'Best epoch: {np.argmin(hist.history["val_loss"])+1}')
# Out:
# Epoch 1/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 64s 172ms/step - loss: 1.3633 - val_loss: 0.5853
# Epoch 2/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 142ms/step - loss: 0.7385 - val_loss: 0.3701
# Epoch 3/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 149ms/step - loss: 0.5425 - val_loss: 0.2829
# Epoch 4/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 149ms/step - loss: 0.4525 - val_loss: 0.2326
# Epoch 5/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 144ms/step - loss: 0.3980 - val_loss: 0.1941
# Epoch 6/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - loss: 0.3579 - val_loss: 0.1654
# Epoch 7/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 142ms/step - loss: 0.3264 - val_loss: 0.1448
# Epoch 8/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 140ms/step - loss: 0.3025 - val_loss: 0.1299
# Epoch 9/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 28s 135ms/step - loss: 0.2820 - val_loss: 0.1175
# Epoch 10/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - loss: 0.2660 - val_loss: 0.1082
# Epoch 11/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 32s 152ms/step - loss: 0.2496 - val_loss: 0.0935
# Epoch 12/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 140ms/step - loss: 0.2339 - val_loss: 0.0842
# Epoch 13/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 145ms/step - loss: 0.2203 - val_loss: 0.0777
# Epoch 14/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 29s 138ms/step - loss: 0.2098 - val_loss: 0.0714
# Epoch 15/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 29s 140ms/step - loss: 0.1994 - val_loss: 0.0663
# Epoch 16/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 145ms/step - loss: 0.1908 - val_loss: 0.0609
# Epoch 17/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 142ms/step - loss: 0.1825 - val_loss: 0.0570
# Epoch 18/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 142ms/step - loss: 0.1756 - val_loss: 0.0527
# Epoch 19/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 148ms/step - loss: 0.1679 - val_loss: 0.0497
# Epoch 20/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 145ms/step - loss: 0.1625 - val_loss: 0.0471
# Epoch 21/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - loss: 0.1568 - val_loss: 0.0438
# Epoch 22/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 142ms/step - loss: 0.1515 - val_loss: 0.0421
# Epoch 23/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - loss: 0.1471 - val_loss: 0.0394
# Epoch 24/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 146ms/step - loss: 0.1424 - val_loss: 0.0374
# Epoch 25/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - loss: 0.1388 - val_loss: 0.0356
# Epoch 26/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 145ms/step - loss: 0.1349 - val_loss: 0.0335
# Epoch 27/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - loss: 0.1319 - val_loss: 0.0326
# Epoch 28/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 141ms/step - loss: 0.1292 - val_loss: 0.0315
# Epoch 29/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 149ms/step - loss: 0.1261 - val_loss: 0.0302
# Epoch 30/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 140ms/step - loss: 0.1244 - val_loss: 0.0291
# Epoch 31/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 141ms/step - loss: 0.1218 - val_loss: 0.0276
# Epoch 32/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 147ms/step - loss: 0.1199 - val_loss: 0.0280
# Epoch 33/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 143ms/step - loss: 0.1181 - val_loss: 0.0266
# Epoch 34/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 145ms/step - loss: 0.1157 - val_loss: 0.0265
# Epoch 35/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 145ms/step - loss: 0.1148 - val_loss: 0.0260
# Epoch 36/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 20s 95ms/step - loss: 0.1138 - val_loss: 0.0247
# Epoch 37/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 19s 88ms/step - loss: 0.1118 - val_loss: 0.0246
# Epoch 38/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 19s 89ms/step - loss: 0.1105 - val_loss: 0.0243
# Epoch 39/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 19s 90ms/step - loss: 0.1102 - val_loss: 0.0245
# Epoch 40/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 19s 89ms/step - loss: 0.1092 - val_loss: 0.0234
# Epoch 41/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 19s 90ms/step - loss: 0.1079 - val_loss: 0.0237
# Epoch 42/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 19s 90ms/step - loss: 0.1068 - val_loss: 0.0234
# Epoch 43/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 19s 91ms/step - loss: 0.1062 - val_loss: 0.0227
# Epoch 44/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 19s 91ms/step - loss: 0.1052 - val_loss: 0.0239
# Epoch 45/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 19s 92ms/step - loss: 0.1043 - val_loss: 0.0227
# Epoch 46/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 19s 91ms/step - loss: 0.1035 - val_loss: 0.0223
# Epoch 47/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - loss: 0.1025 - val_loss: 0.0216
# Epoch 48/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 53s 255ms/step - loss: 0.1023 - val_loss: 0.0214
# Epoch 49/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 308ms/step - loss: 0.1013 - val_loss: 0.0214
# Epoch 50/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 62s 293ms/step - loss: 0.1011 - val_loss: 0.0221
# Epoch 51/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 84s 305ms/step - loss: 0.1006 - val_loss: 0.0212
# Epoch 52/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 64s 306ms/step - loss: 0.0997 - val_loss: 0.0218
# Epoch 53/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 308ms/step - loss: 0.0995 - val_loss: 0.0220
# Epoch 54/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 308ms/step - loss: 0.0986 - val_loss: 0.0206
# Epoch 55/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 314ms/step - loss: 0.0983 - val_loss: 0.0211
# Epoch 56/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 67s 317ms/step - loss: 0.0984 - val_loss: 0.0205
# Epoch 57/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 315ms/step - loss: 0.0981 - val_loss: 0.0207
# Epoch 58/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 60s 287ms/step - loss: 0.0976 - val_loss: 0.0209
# Epoch 59/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 314ms/step - loss: 0.0967 - val_loss: 0.0207
# Epoch 60/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 309ms/step - loss: 0.0962 - val_loss: 0.0207
# Epoch 61/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 67s 320ms/step - loss: 0.0958 - val_loss: 0.0204
# Epoch 62/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 78s 303ms/step - loss: 0.0958 - val_loss: 0.0199
# Epoch 63/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 83s 309ms/step - loss: 0.0954 - val_loss: 0.0203
# Epoch 64/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 313ms/step - loss: 0.0949 - val_loss: 0.0204
# Epoch 65/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 67s 319ms/step - loss: 0.0942 - val_loss: 0.0193
# Epoch 66/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 314ms/step - loss: 0.0938 - val_loss: 0.0199
# Epoch 67/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 67s 317ms/step - loss: 0.0934 - val_loss: 0.0199
# Epoch 68/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 309ms/step - loss: 0.0932 - val_loss: 0.0201
# Epoch 69/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 64s 304ms/step - loss: 0.0929 - val_loss: 0.0192
# Epoch 70/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 310ms/step - loss: 0.0928 - val_loss: 0.0204
# Epoch 71/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 64s 306ms/step - loss: 0.0925 - val_loss: 0.0194
# Epoch 72/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 68s 322ms/step - loss: 0.0923 - val_loss: 0.0189
# Epoch 73/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 67s 317ms/step - loss: 0.0920 - val_loss: 0.0199
# Epoch 74/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 310ms/step - loss: 0.0913 - val_loss: 0.0208
# Epoch 75/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 313ms/step - loss: 0.0915 - val_loss: 0.0195
# Epoch 76/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 82s 313ms/step - loss: 0.0908 - val_loss: 0.0202
# Epoch 77/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 67s 319ms/step - loss: 0.0908 - val_loss: 0.0194
# Epoch 78/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 67s 318ms/step - loss: 0.0902 - val_loss: 0.0200
# Epoch 79/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 64s 307ms/step - loss: 0.0899 - val_loss: 0.0202
# Epoch 80/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 67s 319ms/step - loss: 0.0899 - val_loss: 0.0188
# Epoch 81/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 315ms/step - loss: 0.0897 - val_loss: 0.0199
# Epoch 82/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 315ms/step - loss: 0.0896 - val_loss: 0.0197
# Epoch 83/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 312ms/step - loss: 0.0894 - val_loss: 0.0202
# Epoch 84/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 314ms/step - loss: 0.0891 - val_loss: 0.0202
# Epoch 85/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 67s 321ms/step - loss: 0.0889 - val_loss: 0.0191
# Epoch 86/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 314ms/step - loss: 0.0887 - val_loss: 0.0192
# Epoch 87/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 308ms/step - loss: 0.0881 - val_loss: 0.0195
# Epoch 88/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 315ms/step - loss: 0.0878 - val_loss: 0.0193
# Epoch 89/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 81s 310ms/step - loss: 0.0879 - val_loss: 0.0197
# Epoch 90/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 316ms/step - loss: 0.0872 - val_loss: 0.0198
# Epoch 91/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 64s 303ms/step - loss: 0.0874 - val_loss: 0.0185
# Epoch 92/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 76s 272ms/step - loss: 0.0871 - val_loss: 0.0187
# Epoch 93/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 52s 247ms/step - loss: 0.0873 - val_loss: 0.0191
# Epoch 94/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 96s 316ms/step - loss: 0.0865 - val_loss: 0.0196
# Epoch 95/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 313ms/step - loss: 0.0862 - val_loss: 0.0199
# Epoch 96/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 313ms/step - loss: 0.0865 - val_loss: 0.0192
# Epoch 97/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 313ms/step - loss: 0.0863 - val_loss: 0.0189
# Epoch 98/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 83s 316ms/step - loss: 0.0861 - val_loss: 0.0194
# Epoch 99/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 317ms/step - loss: 0.0857 - val_loss: 0.0183
# Epoch 100/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 66s 315ms/step - loss: 0.0858 - val_loss: 0.0192
# Epoch 101/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 67s 320ms/step - loss: 0.0858 - val_loss: 0.0189
# Epoch 102/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 62s 296ms/step - loss: 0.0854 - val_loss: 0.0184
# Epoch 103/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 64s 303ms/step - loss: 0.0854 - val_loss: 0.0185
# Epoch 104/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 63s 300ms/step - loss: 0.0852 - val_loss: 0.0180
# Epoch 105/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 310ms/step - loss: 0.0846 - val_loss: 0.0189
# Epoch 106/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 64s 306ms/step - loss: 0.0849 - val_loss: 0.0206
# Epoch 107/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 309ms/step - loss: 0.0848 - val_loss: 0.0186
# Epoch 108/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 308ms/step - loss: 0.0846 - val_loss: 0.0186
# Epoch 109/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 64s 305ms/step - loss: 0.0842 - val_loss: 0.0199
# Epoch 110/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 308ms/step - loss: 0.0842 - val_loss: 0.0201
# Epoch 111/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 63s 300ms/step - loss: 0.0844 - val_loss: 0.0190
# Epoch 112/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 64s 307ms/step - loss: 0.0840 - val_loss: 0.0202
# Epoch 113/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 81s 301ms/step - loss: 0.0838 - val_loss: 0.0200
# Epoch 114/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 308ms/step - loss: 0.0835 - val_loss: 0.0184
# Epoch 115/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 69s 327ms/step - loss: 0.0837 - val_loss: 0.0191
# Epoch 116/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 55s 260ms/step - loss: 0.0836 - val_loss: 0.0193
# Epoch 117/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 52s 246ms/step - loss: 0.0831 - val_loss: 0.0197
# Epoch 118/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 53s 252ms/step - loss: 0.0827 - val_loss: 0.0197
# Epoch 119/200
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 52s 247ms/step - loss: 0.0833 - val_loss: 0.0189
# Best epoch: 104

# %%
# ── 12. Reconstruction error per window ───────────────────────────────────
def recon_err(model, X):
    Xp = model.predict(X, verbose=0)
    return np.mean((X - Xp)**2, axis=(1,2))

err_val  = recon_err(ae, W_val_ae)
err_test = recon_err(ae, W_test_ae)

print(f'Val  error — mean:{err_val.mean():.4f} std:{err_val.std():.4f}')
print(f'Test error — mean:{err_test.mean():.4f} std:{err_test.std():.4f}')
# Out:
# Val  error — mean:0.0180 std:0.0308
# Test error — mean:0.0282 std:0.0705

# %%
# ── 13. Hyperparameter sweep α∈{0.05,0.10,0.15} × β∈{1,2,3} ──────────────
# Paper Table 3 (MetroPT1): best = α=0.05, β=1

TAU_FAIL = 0.5

def low_pass(y_raw, alpha):
    z = np.zeros(len(y_raw))
    z[0] = y_raw[0]
    for t in range(1, len(y_raw)):
        z[t] = z[t-1] + alpha*(y_raw[t] - z[t-1])
    return z

def interval_metrics(y_true, y_pred):
    tf_set = set(np.where(y_true==1)[0])
    pf_set = set(np.where(y_pred==1)[0])
    tp = len(tf_set & pf_set)
    fp = len(pf_set - tf_set)
    fn = len(tf_set - pf_set)
    prec = tp/(tp+fp) if (tp+fp)>0 else 0.0
    rec  = tp/(tp+fn) if (tp+fn)>0 else 0.0
    f1   = 2*prec*rec/(prec+rec) if (prec+rec)>0 else 0.0
    iou  = tp/len(tf_set|pf_set) if len(tf_set|pf_set)>0 else 0.0
    return dict(Precision=round(prec,3), Recall=round(rec,3),
                F1=round(f1,3), IoU=round(iou,3))

q99 = np.percentile(err_val, 99)
sweep_rows = []
for alpha in [0.05, 0.10, 0.15]:
    for beta in [1, 2, 3]:
        tau  = beta * q99
        y_r  = (err_test > tau).astype(float)
        pf   = low_pass(y_r, alpha)
        yp   = (pf > TAU_FAIL).astype(int)
        m    = interval_metrics(y_test_win, yp)
        sweep_rows.append({'α':alpha,'β':beta,**m})

sweep_df = pd.DataFrame(sweep_rows)
print('Hyperparameter sweep (Table 3 equivalent):')
print(sweep_df.to_string(index=False))

# Best config: α=0.05, β=1 (paper best)
ALPHA, BETA = 0.05, 1
tau_anom = BETA * q99
print(f'\nUsing best config: α={ALPHA}, β={BETA}, τ_anom={tau_anom:.4f}')
# Out:
# Hyperparameter sweep (Table 3 equivalent):
#    α  β  Precision  Recall    F1   IoU
# 0.05  1      0.664   0.828 0.737 0.584
# 0.05  2      0.780   0.811 0.795 0.660
# 0.05  3      0.789   0.795 0.792 0.655
# 0.10  1      0.673   0.943 0.785 0.646
# 0.10  2      0.807   0.926 0.863 0.758
# 0.10  3      0.854   0.910 0.881 0.787
# 0.15  1      0.504   0.967 0.663 0.496
# 0.15  2      0.750   0.959 0.842 0.727
# 0.15  3      0.839   0.943 0.888 0.799
#
# Using best config: α=0.05, β=1, τ_anom=0.1074

# %%
# ── 14. Final p(failure) with best config ─────────────────────────────────
y_raw     = (err_test > tau_anom).astype(float)
p_failure = low_pass(y_raw, ALPHA)
y_pred    = (p_failure > TAU_FAIL).astype(int)

metrics = interval_metrics(y_test_win, y_pred)
print('=' * 50)
print(f'Failure Detection Results (α={ALPHA}, β={BETA})')
print('=' * 50)
for k,v in metrics.items():
    print(f'  {k:12s}: {v}')

# Check early detection (paper goal: detect 2h before LPS)
print('\nEarly detection check:')
for f in FAILURES:
    goal = f['goal']  # 2h before LPS
    # Find first predicted window before LPS
    pred_times = ts_test_pd[y_pred == 1]
    f_preds = pred_times[
        (pred_times >= f['start'] - pd.Timedelta(hours=3)) &
        (pred_times <= f['lps_time'])
    ]
    if len(f_preds) > 0:
        first = f_preds.min()
        lead  = (f['lps_time'] - first).total_seconds()/60
        ok    = '✓ GOAL MET' if first <= goal else '✗'
        print(f"  {f['name']}: detected at {first} | {lead:.0f} min before LPS | {ok}")
    else:
        print(f"  {f['name']}: NOT DETECTED")
# Out:
# ==================================================
# Failure Detection Results (α=0.05, β=1)
# ==================================================
#   Precision   : 0.664
#   Recall      : 0.828
#   F1          : 0.737
#   IoU         : 0.584
#
# Early detection check:
#   Air Leak: NOT DETECTED
#   Oil Leak: NOT DETECTED

# %%
# ── 15. Plot p(failure) — Fig.4 equivalent ────────────────────────────────
fig, axes = plt.subplots(3, 1, figsize=(16, 12))

# Top: full test period
ax = axes[0]
ax.plot(ts_test_pd, p_failure, color='steelblue', lw=0.8, label='p(failure)')
ax.axhline(TAU_FAIL, color='red', ls='--', lw=1, label=f'τ_fail={TAU_FAIL}')
for f in FAILURES:
    ax.axvspan(f['start'], f['end'], alpha=0.2, color='gray')
    ax.axvline(f['lps_time'], color='black', ls=':', lw=1)
ax.set_title('p(failure) — Full Test Period (MetroPT1)', fontsize=13)
ax.set_ylabel('p(failure)')
ax.set_ylim(-0.05, 1.15)
ax.legend()

# Middle: Air Leak zoom
for ax, f in zip(axes[1:], FAILURES):
    zoom_s = f['start'] - pd.Timedelta(hours=3)
    zoom_e = f['end']   + pd.Timedelta(hours=3)
    mask   = (ts_test_pd >= zoom_s) & (ts_test_pd <= zoom_e)
    ax.plot(ts_test_pd[mask], p_failure[mask], color='steelblue', lw=1.2)
    ax.axhline(TAU_FAIL, color='red', ls='--', lw=1)
    ax.axvspan(f['start'], f['end'], alpha=0.2, color='gray', label='Failure')
    ax.axvline(f['lps_time'], color='black', ls=':', lw=1.5, label='LPS signal')
    ax.axvline(f['goal'], color='green', ls='--', lw=1, label='Goal (2h before LPS)')
    ax.set_title(f"Zoom: {f['name']}", fontsize=12)
    ax.set_ylabel('p(failure)')
    ax.set_ylim(-0.05, 1.15)
    ax.legend(fontsize=8)

plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, 'p_failure_metropt2.png'), dpi=150, bbox_inches='tight')
plt.show()

# %%
# ── 16. Time-aggregated features φ(x) for rule learning (paper §4.2) ──────
# φ(x) = [variance, min, max, mean] per sensor over 30-min window

def aggregate_window(win):  # win: (L, C)
    return np.concatenate([
        np.var(win,  axis=0),
        np.min(win,  axis=0),
        np.max(win,  axis=0),
        np.mean(win, axis=0)
    ])

agg_names = (
    [f'{c}_var'  for c in FEATURE_COLS] +
    [f'{c}_min'  for c in FEATURE_COLS] +
    [f'{c}_max'  for c in FEATURE_COLS] +
    [f'{c}_mean' for c in FEATURE_COLS]
)

# Use full W_test (L=1800) for aggregation — not subsampled
phi_test  = np.array([aggregate_window(W_test[i])  for i in range(len(W_test))])
phi_train = np.array([aggregate_window(W_train[i]) for i in range(len(W_train))])

print(f'φ(x) shape: {phi_test.shape}  ({len(agg_names)} features)')
print(f'Feature names sample: {agg_names[:4]} ... {agg_names[-4:]}')
# Out:
# φ(x) shape: (26334, 60)  (60 features)
# Feature names sample: ['TP2_var', 'TP3_var', 'H1_var', 'DV_pressure_var'] ... ['MPG_mean', 'Pressure_switch_mean', 'Oil_level_mean', 'Caudal_impulses_mean']

# %%
# ── 17. Online Rule-Learning — Algorithm 1 ─────────────────────────────────

class OnlineRuleLearner:
    """
    Exact implementation of Algorithm 1 (paper §4.2).
    States: Normal (p < τ_warn) → Warning (p > τ_warn) → Failure (p > τ_fail)
    Rules: Decision Trees on time-aggregated features φ(x)
    Minimum support θ = 0.99
    """
    def __init__(self, tau_warn=0.3, tau_fail=0.5, theta=0.99,
                 feature_names=None, max_history=5000):
        self.tau_warn      = tau_warn
        self.tau_fail      = tau_fail
        self.theta         = theta
        self.feature_names = feature_names
        self.max_history   = max_history
        self.H = []   # history: normal windows
        self.B = []   # buffer: warning/failure windows
        self.rules = []
        self.failure_rules = {}
        self.fail_idx = 0
        self._in_fail = False

    def _learn_rules(self, B, H):
        X = np.vstack([np.array(B), np.array(H)])
        y = np.array([1]*len(B) + [0]*len(H))
        best_tree, best_sup = None, 0.0
        for depth in [1, 2, 3, 4, 5]:
            dt = DecisionTreeClassifier(max_depth=depth, random_state=SEED)
            dt.fit(X, y)
            sup = dt.predict(np.array(B)).mean()
            if sup >= self.theta:
                return dt, sup  # minimal depth satisfying θ
            if sup > best_sup:
                best_tree, best_sup = dt, sup
        return best_tree, best_sup

    def process(self, phi_seq, p_fail_seq):
        T = len(phi_seq)
        prev_p = 0.0
        for t in range(T):
            pt  = p_fail_seq[t]
            phi = phi_seq[t]
            is_warning = pt > self.tau_warn
            is_failure = pt > self.tau_fail
            # Algorithm 1 lines 6-11
            if is_warning:
                self.B.append(phi)
            else:
                self.B = []
                if len(self.H) >= self.max_history:
                    self.H.pop(0)
                self.H.append(phi)
            # Algorithm 1 lines 12-15
            if is_failure and len(self.B) > 0 and len(self.H) > 0:
                tree, sup = self._learn_rules(self.B, self.H)
                if tree is not None:
                    self.rules = [(tree, sup)]
                if not self._in_fail:
                    self._in_fail = True
            # Algorithm 1 lines 16-18: failure_stop
            if self._in_fail and pt <= self.tau_fail:
                self._in_fail = False
                if self.rules:
                    tree, sup = self.rules[0]
                    self.failure_rules[self.fail_idx] = {
                        'tree': tree, 'support': sup,
                        'nA': tree.get_depth()
                    }
                    self.fail_idx += 1
                self.B = []
                self.rules = []
            prev_p = pt
        return self.failure_rules

print('OnlineRuleLearner ready.')
# Out:
# OnlineRuleLearner ready.

# %%
# ── 18. Run rule learning ──────────────────────────────────────────────────
phi_train_normal = phi_train[y_train_win == 0]
# Subsample history to 3000 max
if len(phi_train_normal) > 3000:
    idx = np.random.choice(len(phi_train_normal), 3000, replace=False)
    phi_train_normal = phi_train_normal[idx]

learner = OnlineRuleLearner(
    tau_warn=0.3, tau_fail=TAU_FAIL,
    theta=0.99, feature_names=agg_names, max_history=3000
)
learner.H = list(phi_train_normal)

failure_rules = learner.process(phi_test, p_failure)

print(f'Failures with extracted rules: {len(failure_rules)}')
for i, info in failure_rules.items():
    print(f'  Failure {i}: support={info["support"]:.4f}, nA={info["nA"]}')
# Out:
# Failures with extracted rules: 3
#   Failure 0: support=1.0000, nA=4
#   Failure 1: support=1.0000, nA=2
#   Failure 2: support=1.0000, nA=3

# %%
# ── 19. Display extracted rules (Tables 5 & 6 equivalent) ─────────────────
failure_names = ['Air Leak', 'Oil Leak']

for i, info in failure_rules.items():
    fname = failure_names[i] if i < len(failure_names) else f'Failure {i}'
    print(f'\n══ {fname} ══')
    print(f'   Support : {info["support"]:.4f}')
    print(f'   nA      : {info["nA"]}')
    print('\n   Rule (Decision Tree):')
    print(export_text(info['tree'], feature_names=agg_names))
    # Top features
    imp = info['tree'].feature_importances_
    top = np.argsort(imp)[::-1][:3]
    print('   Top features:')
    for j in top:
        if imp[j] > 0:
            print(f'     {agg_names[j]:40s}: {imp[j]:.4f}')
# Out:
# ══ Air Leak ══
#    Support : 1.0000
#    nA      : 4
#
#    Rule (Decision Tree):
# |--- Flowmeter_min <= -0.32
# |   |--- H1_max <= 0.81
# |   |   |--- H1_max <= 0.78
# |   |   |   |--- class: 0
# |   |   |--- H1_max >  0.78
# |   |   |   |--- Oil_temperature_min <= -1.56
# |   |   |   |   |--- class: 0
# |   |   |   |--- Oil_temperature_min >  -1.56
# |   |   |   |   |--- class: 1
# |   |--- H1_max >  0.81
# |   |   |--- class: 1
# |--- Flowmeter_min >  -0.32
# |   |--- H1_min <= -2.75
# |   |   |--- class: 0
# |   |--- H1_min >  -2.75
# |   |   |--- class: 1
#
#    Top features:
#      Flowmeter_min                           : 0.7932
#      H1_max                                  : 0.1164
#      Oil_temperature_min                     : 0.0783
#
# ══ Oil Leak ══
#    Support : 1.0000
#    nA      : 2
#
#    Rule (Decision Tree):
# |--- TP3_mean <= -2.66
# |   |--- class: 1
# |--- TP3_mean >  -2.66
# |   |--- DV_pressure_min <= -0.04
# |   |   |--- class: 0
# |   |--- DV_pressure_min >  -0.04
# |   |   |--- class: 1
#
#    Top features:
#      TP3_mean                                : 0.8207
#      DV_pressure_min                         : 0.1793
#
# ══ Failure 2 ══
#    Support : 1.0000
#    nA      : 3
#
#    Rule (Decision Tree):
# |--- H1_max <= 0.78
# |   |--- Caudal_impulses_var <= 78.51
# |   |   |--- TP2_max <= 3.34
# |   |   |   |--- class: 0
# |   |   |--- TP2_max >  3.34
# |   |   |   |--- class: 1
# |   |--- Caudal_impulses_var >  78.51
# |   |   |--- class: 1
# |--- H1_max >  0.78
# |   |--- Flowmeter_min <= -0.37
# |   |   |--- class: 0
# |   |--- Flowmeter_min >  -0.37
# |   |   |--- TP3_var <= 15.84
# |   |   |   |--- class: 1
# |   |   |--- TP3_var >  15.84
# |   |   |   |--- class: 0
#
#    Top features:
#      H1_max                                  : 0.4927
#      Flowmeter_min                           : 0.1931
#      Caudal_impulses_var                     : 0.1862

# %%
# ── 20. AMRules baseline comparison (paper §5.2) ──────────────────────────
# AMRules: depth-1 DT on per-window data (not aggregated) → low support

fail_idx_wins = np.where(y_pred == 1)[0]
norm_idx_wins = np.where(y_pred == 0)[0]

amr_results = {}
if len(fail_idx_wins) > 0 and len(norm_idx_wins) > 0:
    for i, fname in enumerate(failure_names):
        f = FAILURES[i]
        # Windows belonging to this specific failure
        f_mask = (
            (ts_test_pd >= f['start']) &
            (ts_test_pd <= f['end']) &
            (y_pred == 1)
        )
        f_wins = np.where(f_mask)[0]
        if len(f_wins) == 0:
            print(f'{fname}: no windows detected — AMRules N/A')
            continue

        X_f = phi_test[f_wins]
        n_norm = min(len(f_wins)*10, len(norm_idx_wins))
        X_n = phi_test[norm_idx_wins[:n_norm]]
        X_all = np.vstack([X_f, X_n])
        y_all = np.array([1]*len(X_f) + [0]*len(X_n))

        amr = DecisionTreeClassifier(max_depth=1, random_state=SEED)
        amr.fit(X_all, y_all)
        sup = amr.predict(X_f).mean()
        amr_results[fname] = {'support': sup, 'nA': 1,
                               'rule': export_text(amr, feature_names=agg_names)}
        print(f'{fname} — AMRules support: {sup:.4f}')
        print(amr_results[fname]['rule'])
# Out:
# Air Leak — AMRules support: 0.9077
# |--- TP3_max <= -6.21
# |   |--- class: 1
# |--- TP3_max >  -6.21
# |   |--- class: 0
#
# Oil Leak — AMRules support: 1.0000
# |--- Reservoirs_mean <= 1.27
# |   |--- class: 0
# |--- Reservoirs_mean >  1.27
# |   |--- class: 1

# %%
# ── 20. AMRules baseline comparison (paper §5.2) ──────────────────────────
# AMRules: depth-1 DT on per-window data (not aggregated) → low support
# Note: paper_amr values below are for MetroPT1 (adjust if different from paper)
)
# Out:
#   Cell In[22], line 4
#     )
#     ^
# SyntaxError: unmatched ')'

# %%
# ── 22. Flowmeter sensor analysis (paper Fig.6 + §5.3) ────────────────────
# Paper: "Flowmeter usually has small values, with sporadic peaks
#         aligning perfectly with the observed failures"

if 'Flowmeter' in FEATURE_COLS:
    fm_idx = FEATURE_COLS.index('Flowmeter')
    fm_per_win = np.array([W_test[i,:,fm_idx].max() for i in range(len(W_test))])

    fig, axes = plt.subplots(2, 1, figsize=(16, 8))

    ax1 = axes[0]
    ax1.plot(ts_test_pd, fm_per_win, color='green', lw=0.8, label='Flowmeter_max')
    for f in FAILURES:
        ax1.axvspan(f['start'], f['end'], alpha=0.2, color='gray', label=f['name'])
        ax1.axvline(f['lps_time'], color='black', ls=':', lw=1)
    ax1.set_title('Flowmeter_max — Full Test Period (Fig.6 equivalent)', fontsize=12)
    ax1.set_ylabel('Flowmeter (m³/h)')
    ax1.legend()

    # Paper rule: Flowmeter_max > ~16 → failure
    ax1.axhline(16.0, color='red', ls='--', lw=1, label='Threshold ~16 m³/h')

    ax2 = axes[1]
    ot_idx = FEATURE_COLS.index('Oil_temperature')
    ot_per_win = np.array([W_test[i,:,ot_idx].max() for i in range(len(W_test))])
    ax2.plot(ts_test_pd, ot_per_win, color='sienna', lw=0.8, label='Oil_temperature_max')
    for f in FAILURES:
        ax2.axvspan(f['start'], f['end'], alpha=0.2, color='gray')
    ax2.set_title('Oil_temperature_max — Full Test Period', fontsize=12)
    ax2.set_ylabel('Oil Temperature (°C)')
    ax2.legend()

    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'sensor_analysis_metropt2.png'), dpi=150, bbox_inches='tight')
    plt.show()

# %%
# ── 23. Training loss curve ────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(hist.history['loss'],     label='Train Loss')
ax.plot(hist.history['val_loss'], label='Val Loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('MSE')
ax.set_title('Convolutional AE Training Curve — MetroPT1')
ax.legend()
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, 'ae_loss_metropt1.png'), dpi=150)
plt.show()

# %%
# ── 24. Final Summary ──────────────────────────────────────────────────────
print('=' * 60)
print('FINAL RESULTS — MetroPT1')
print('=' * 60)
print(f'Dataset      : MetroPT1 (January–June 2022)')
print(f'Train cutoff : 2022-02-10  ← day before Air Leak (both failures in Test)')
print(f'AE           : Conv N=10, dilation=2^i, 30 kernels, embed=32')
print(f'α={ALPHA}, β={BETA}, τ_fail={TAU_FAIL}')
print(f'\n── Failure Detection ──')
for k,v in metrics.items():
    print(f'  {k:12s}: {v}')
print(f'\n── Paper reported (Table 3 best): F1=1.0 ──')
print(f'\n── Rules ──')
for i, info in failure_rules.items():
    fname = failure_names[i] if i < len(failure_names) else f'F{i}'
    print(f'  {fname}: support={info["support"]:.4f}, nA={info["nA"]}')
    print(f'  Paper: Flowmeter_max threshold (Air Leak & Oil Leak), support≈0.999')
print('\nNotebook 3 (MetroPT1) complete ✓')
# Out:
# ============================================================
# FINAL RESULTS — MetroPT1
# ============================================================
# Dataset      : MetroPT1 (January–June 2022)
# Train cutoff : 2022-02-10  ← day before Air Leak (both failures in Test)
# AE           : Conv N=10, dilation=2^i, 30 kernels, embed=32
# α=0.05, β=1, τ_fail=0.5
#
# ── Failure Detection ──
#   Precision   : 0.664
#   Recall      : 0.828
#   F1          : 0.737
#   IoU         : 0.584
#
# ── Paper reported (Table 3 best): F1=1.0 ──
#
# ── Rules ──
#   Air Leak: support=1.0000, nA=4
#   Paper: Flowmeter_max threshold (Air Leak & Oil Leak), support≈0.999
#   Oil Leak: support=1.0000, nA=2
#   Paper: Flowmeter_max threshold (Air Leak & Oil Leak), support≈0.999
#   F2: support=1.0000, nA=3
#   Paper: Flowmeter_max threshold (Air Leak & Oil Leak), support≈0.999
#
# Notebook 3 (MetroPT1) complete ✓

# %%
# ── 25. Paper vs Reproduction Comparison ─────────────────────────────

paper_results = {
    "Precision": 1.000,
    "Recall": 1.000,
    "F1": 1.000,
    "IoU": 0.900  # MetroPT1 reference value (paper Table 3)
}

our_results = {
    "Precision": metrics["Precision"],
    "Recall": metrics["Recall"],
    "F1": metrics["F1"],
    "IoU": metrics["IoU"]
}

comparison = pd.DataFrame({
    "Metric": paper_results.keys(),
    "Paper": paper_results.values(),
    "Our Implementation": our_results.values()
})

print("\n=== Paper vs Our Results ===")
print(comparison.to_string(index=False))
# Out:
# === Paper vs Our Results ===
#    Metric  Paper  Our Implementation
# Precision    1.0               0.664
#    Recall    1.0               0.828
#        F1    1.0               0.737
#       IoU    0.9               0.584

# %%
# ── 26. Early Detection Comparison ─────────────────────────────

rows = []

# NOTE: كلا العطلين في فبراير (قبل CUTOFF=15 مارس) → في Train
# النموذج لا يمكنه اكتشافهما مسبقاً لأنهما ليسا في Test
# هذه الخلية ستعطي DataFrame فارغاً — وهذا صحيح ومتوقع
paper_early = {
    "Air Leak": 'N/A — failure in Train period',
    "Oil Leak": 'N/A — failure in Train period'
}

for f in FAILURES:

    pred_times = ts_test_pd[y_pred == 1]

    f_preds = pred_times[
        (pred_times >= f['start'] - pd.Timedelta(hours=3))
        & (pred_times <= f['lps_time'])
    ]

    if len(f_preds) > 0:
        first = f_preds.min()
        lead = (f['lps_time'] - first).total_seconds() / 60

        rows.append({
            "Failure": f["name"],
            "Paper (min)": paper_early.get(f["name"], np.nan),
            "Our Result (min)": round(lead, 1)
        })

early_df = pd.DataFrame(rows)

print("\n=== Early Detection ===")
print(early_df.to_string(index=False))
# Out:
# === Early Detection ===
# Empty DataFrame
# Columns: []
# Index: []

# %%
# ── 27. Rule Comparison ─────────────────────────────

paper_rules = {
    "Air Leak": "Flowmeter_max > threshold (MetroPT1)",
    "Oil Leak": "Flowmeter_max > threshold (MetroPT1)"
}

rows = []

for i, info in failure_rules.items():

    if i >= len(failure_names):
        print(f"Index {i} not found in failure_names")
        continue

    fname = failure_names[i]

    rows.append({
        "Failure": fname,
        "Paper Rule": paper_rules.get(fname, "-"),
        "Support": round(info["support"], 4),
        "nA": info["nA"]
    })

rules_df = pd.DataFrame(rows)

print("\n=== Rule Comparison ===")
print(rules_df.to_string(index=False))
# Out:
# Index 2 not found in failure_names
#
# === Rule Comparison ===
#  Failure                           Paper Rule  Support  nA
# Air Leak Flowmeter_max > threshold (MetroPT1)      1.0   4
# Oil Leak Flowmeter_max > threshold (MetroPT1)      1.0   2

# %%
# ── 28. Confusion Matrix Stats ─────────────────────────────

tp = np.sum((y_pred == 1) & (y_test_win == 1))
fp = np.sum((y_pred == 1) & (y_test_win == 0))
fn = np.sum((y_pred == 0) & (y_test_win == 1))
tn = np.sum((y_pred == 0) & (y_test_win == 0))

print("\n=== Confusion Matrix ===")
print(f"TP = {tp}")
print(f"FP = {fp}")
print(f"FN = {fn}")
print(f"TN = {tn}")
# Out:
# === Confusion Matrix ===
# TP = 101
# FP = 51
# FN = 21
# TN = 26161
